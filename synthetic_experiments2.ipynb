# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd
import scipy.stats, scipy.special

from collections import Counter

from conformal_utils import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# This notebook is a copy of `synthetic_experiments1.ipynb`, but the data generation process is modified to output 1000 classes
#
# **Goal of this notebook**: Run some simulations to sanity check my code to see if class-balanced conformal inference will outperform standard conformal inference as we increase the amount of calibration data

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Data generation procedure: Mixture of Gaussians
#
# #### Phase I:
# 1. Randomly select a class $Y_i$ with probability determined by `P_Y`
# 2. Select the corresponding mean $\mu$ given by `means`
# 3. Sample $X_i \sim N(\mu, 1)$
# 4. Repeat steps 1-3 `num_samples` number of times
#
# #### Phase II:
# 1. Compute $P(Y = k |X_i) = \frac{P(X_i | Y = k)P(Y_i = k)}{P(X_i)}$
# 2. Define score = $P(Y = \mathsf{truelabel} |X_i)$

# %%
def generate_synthetic_data(num_samples, means, std_dev, P_Y, return_log=False):
    '''
    Inputs:
        - num_samples: Number of samples to generate
        - means: array of the means of each Gaussian in the mixture of Gaussians 
        - std_dev: Scalar representing standard deviation of each Gaussian (all Gaussians have the same SD)
        - P_Y: array of same length as means. ith element is probability that true label is class i
        - return_log: if True, class_probs are returned as log of class probabilities 
    Outputs:
        - true_labels: num_samples length vector
        - class_probs: num_samples x 5 array containing P(Y_i = k | X_i) for each class k 
          or log(P(Y_i = k | X_i)) if return_log is set to True
        
    '''

    # --- Phase I ---
    # Generate mixture of Gaussians
    means = np.array(means) 
    std_devs = std_dev * np.ones((len(means),))
    P_Y = np.array(P_Y) 

    num_classes = len(means)

    # Select true labels randomly according to P_Y
    true_labels = np.random.choice(np.arange(num_classes), num_samples, p=P_Y)
    # Simulate values from corresponding Gaussians
    X = np.random.normal(loc=means[true_labels], scale=std_devs[true_labels], size=(num_samples,))
    
    # --- Phase II ---
    # Compute vector P(Y|X_i) for each X_i
    class_probs = np.zeros((num_samples, num_classes))
    if return_log: # Use log scale
        for k in range(num_classes):
            log_P_X_given_Y = scipy.stats.norm(loc=means[k], scale=std_devs[k]).logpdf(X)
            class_probs[:,k] = log_P_X_given_Y + np.log(P_Y[k]) # P(Y and X_i)

        # Normalize each row to get P(Y and X_i) / P(X_i) = P(Y|X_i)
        class_probs = class_probs - np.expand_dims(scipy.special.logsumexp(class_probs, axis=1), axis=1)
    else: 
        for k in range(num_classes):
            P_X_given_Y = scipy.stats.norm(loc=means[k], scale=std_devs[k]).pdf(X)
            class_probs[:,k] = P_X_given_Y * P_Y[k] # P(Y and X_i)

        # Normalize each row to get P(Y and X_i) / P(X_i) = P(Y|X_i)
        class_probs = class_probs / np.expand_dims(np.sum(class_probs, axis=1), axis=1)
    
    class_scores = 1 - class_probs
    
    return true_labels, class_scores

# For debugging purposes, generate uniform data with uniform scores
def generate_uniform_data(num_samples, num_classes):
    class_scores = np.random.rand(num_samples, num_classes)
    true_labels = np.random.choice(np.arange(num_classes), size=(num_samples,))
    
    return true_labels, class_scores

# %%
np.array([[1, 2, 3], [4, 5, 6], [2, 2, 2]]) - np.array([[0], [5], [10]])
# Out:
# array([[ 1,  2,  3],
#        [-1,  0,  1],
#        [-8, -8, -8]])

# %% [markdown]
# # What is the effect of increasing the size of the calibration dataset?

# %%
calibration_data_size = 1000 
test_data_size = 10000
num_trials = 1 # Number of synthetic datasets to generate for each parameter setting

# %%
# %%time 

np.random.seed(1)

# np.set_printoptions(suppress=True) # Suppress scientific notation when printing arrays
# np.set_printoptions(suppress=False)

num_classes = 1000
# num_classes = 200

# Specify calibration_data_size's to use
calibration_data_sizes = [5000, 10000, 25000, 50000, 100000]
test_data_size = 50000

# Fixed settings (held constant throughout experiment)
alpha = .05 # Specifies coverage level 
std_dev = .5
means = np.random.rand(num_classes,)*100
P_Y = np.ones((num_classes,)) / num_classes # Uniform class balance

# Run experiment
test_marginal_coverage = np.zeros((len(calibration_data_sizes), num_trials))
test_class_coverage = np.zeros((len(calibration_data_sizes), num_trials, num_classes))
for i, calibration_data_size in enumerate(calibration_data_sizes):
    print('calibration_data_size:', calibration_data_size)
    for j in range(num_trials):
        
# #         # DEBUGGING: Generate uniform data
#         cal_true_labels, cal_class_scores = generate_uniform_data(calibration_data_size, num_classes)
#         test_true_labels, test_class_scores = generate_uniform_data(test_data_size, num_classes)
        
        
        # Generate datasets of desired size
        cal_true_labels, cal_class_scores = generate_synthetic_data(calibration_data_size, means, std_dev, P_Y, return_log=False)
        test_true_labels, test_class_scores = generate_synthetic_data(test_data_size, means, std_dev, P_Y, return_log=False)
        
#         print('cal_class_probs', cal_class_probs[:3,:])

        # Compute standard score quantile
        standard_ci_qhat = compute_qhat(cal_class_scores, cal_true_labels, alpha=alpha)
        print('standard_ci_qhat', standard_ci_qhat)

        # Compute class-specific score quantiles
        qhats = compute_class_specific_qhats(cal_class_scores, cal_true_labels, alpha=alpha, default_qhat=np.inf)
#         qhats = compute_class_specific_qhats(cal_class_scores, cal_true_labels, alpha=alpha, default_qhat=standard_ci_qhat)

#         print('qhats', qhats)
        
        # Create prediction sets for test set
        set_preds = create_cb_prediction_sets(test_class_scores, qhats)
        avg_set_size = np.mean([len(x) for x in set_preds])
        print(f'Average set size {avg_set_size:.2f}')

        # Compute marginal coverage for test set
        test_marginal_coverage[i,j] = compute_coverage(test_true_labels, set_preds)
        
        # Compute class-specific coverage for test set
        class_specific_cov = compute_class_specific_coverage(test_true_labels, set_preds)
        test_class_coverage[i,j,:] = class_specific_cov
    print()
# Out:
# calibration_data_size: 5000
# standard_ci_qhat 0.9881542894546381
# Warning: Class 0 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 1 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 2 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 3 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 4 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 5 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 6 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 7 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 8 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 9 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 10 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 11 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 12 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 13 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class
does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 341 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 342 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 343 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 344 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 345 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 346 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 347 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 348 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 349 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 350 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 351 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 352 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 353 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 354 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 355 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 356 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 357 does not appear in the calibration set, so default q_hat value of inf will be used
# Warning: Class 358 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 359 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 360 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 361 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 362 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 363 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 364 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 365 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 366 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 367 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 368 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 369 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 370 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 371 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 372 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 373 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 374 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 375 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 376 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 377 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 378 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 379 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 380 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 381 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 382 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 383 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 384 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 385 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 386 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 387 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 388 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 389 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 390 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 391 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 392 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 393 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 394 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 395 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 396 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# ...
# Warning: Class 972 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 973 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 974 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 975 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 976 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 977 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 978 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 979 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 980 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 981 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 982 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 983 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 984 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 985 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 986 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 987 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 988 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 989 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 990 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 991 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 992 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 993 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 994 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 995 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 996 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 997 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 998 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 999 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Average set size 995.14
#
# calibration_data_size: 25000
# standard_ci_qhat 0.9888513151404966
# Warning: Class 1 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 5 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 24 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 31 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 49 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 78 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 99 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 121 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 144 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 172 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 173 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 186 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 191 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 202 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 212 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 225 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 236 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 239 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 242 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 261 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 271 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 286 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 291 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 294 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 298 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 302 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 306 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 310 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 315 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 320 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 358 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 363 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 365 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 368 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 382 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 392 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 405 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 407 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 423 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 455 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 456 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 467 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 470 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 480 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 484 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 491 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 494 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 500 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 515 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 533 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 540 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 547 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 552 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 563 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 590 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 599 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 602 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 614 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 616 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 620 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 643 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 653 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 683 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 685 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 688 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 691 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 693 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 703 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 762 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 774 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 781 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 798 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 807 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 808 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 809 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 820 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 821 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 823 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 827 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 829 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 852 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 855 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 866 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 879 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 904 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 910 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 918 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 919 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 920 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 924 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 936 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 941 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 945 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 950 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 952 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 965 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 966 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 968 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 978 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 987 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Warning: Class 989 does not appear enough times to compute a proper quantile, so default q_hat value of inf will be used
# Average set size 122.16
#
# calibration_data_size: 50000
# standard_ci_qhat 0.9882594525600426
# Average set size 22.17
#
# calibration_data_size: 100000
# standard_ci_qhat 0.9882206038034266
# Average set size 21.11
#
# CPU times: user 52.3 s, sys: 6.67 s, total: 59 s
# Wall time: 1min 2s

# %%
avg_class_coverage = np.mean(test_class_coverage, axis=(1,2)) # Class coverage averaged across classes
sd_class_coverage = np.std(test_class_coverage, axis=(1,2))
test_marginal_coverage = np.squeeze(test_marginal_coverage)

df = pd.DataFrame({'calibration_data_size': calibration_data_sizes, 
                   'marginal_coverage': test_marginal_coverage, 
                   'avg_class_coverage': avg_class_coverage,
                   'sd_class_coverage': sd_class_coverage})

df
# Out:
#    calibration_data_size  marginal_coverage  avg_class_coverage  \
# 0                   5000            1.00000            1.000000
# 1                  10000            0.99982            0.999820
# 2                  25000            0.96774            0.967918
# 3                  50000            0.96224            0.962638
# 4                 100000            0.95390            0.953603
#
#    sd_class_coverage
# 0           0.000000
# 1           0.005009
# 2           0.044101
# 3           0.037159
# 4           0.037052
